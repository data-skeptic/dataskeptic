# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import datetime as datetime

# %%
df = pd.read_csv('snacks.csv', sep='\t')
df['Date'] = pd.to_datetime(df['Date'])
df['woy'] = df['Date'].apply(lambda x: x.weekofyear)
df['y'] = df['Date'].apply(lambda x: x.year)

# %%
df.tail()
# Out:
#     Ep ID       Date                                      Food  \
# 55    289 2014-05-04             greek yogurt with maple syrup
# 56    288 2014-04-27  satay chicken and rice with peanut sauce
# 57    287 2014-04-20                                 chocolate
# 58    286 2014-04-13                                         x
# 59    285 2014-04-06             miso soup with pickled ginger
#
#     Approximate calories  woy     y
# 55                   280   18  2014
# 56                   944   17  2014
# 57                   546   16  2014
# 58                     0   15  2014
# 59                    90   14  2014

# %%
plt.figure(figsize=(15,5))
plt.bar(df['Ep ID'], df['Approximate calories'])
plt.xlabel('Episode #')
plt.ylabel('Estimated calories')
plt.title('Richard runs downstairs and gets a snack of...')
ax1 = plt.gca()
#ax1.set_xticks(np.arange(len(df['Ep ID'])))
#ax1.set_xticklabels(df['Ep ID'])
ax2 = ax1.twiny()
ax2.set_xticks(np.arange(len(df['Ep ID'])))
ax2.set_xticklabels(df['Ep ID'])
plt.show()
